# %%
import pandas as pd
import numpy as np 
import nltk
import sklearn
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/data/justice.csv')

# %%
df["disposition"].value_counts()
# Out:
# reversed/remanded            1073
# affirmed                     1007
# reversed                      585
# vacated/remanded              430
# reversed in-part/remanded      61
# none                           41
# reversed in-part               22
# vacated                         7
# vacated in-part/remanded        5
# Name: disposition, dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# ID                      0
# name                    0
# href                    0
# docket                  0
# term                    0
# first_party             1
# second_party            1
# facts                   0
# facts_len               0
# majority_vote           0
# minority_vote           0
# first_party_winner     15
# decision_type           7
# disposition            72
# issue_area            142
# dtype: int64

# %%
df["issue_area"].value_counts()
# Out:
# Criminal Procedure      859
# Civil Rights            568
# Economic Activity       542
# First Amendment         353
# Judicial Power          342
# Due Process             128
# Federalism              125
# Privacy                  70
# Unions                   60
# Federal Taxation         51
# Attorneys                37
# Miscellaneous            20
# Private Action            4
# Interstate Relations      2
# Name: issue_area, dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0     ID                     name  \
# 1           1  50613      Stanley v. Illinois
# 2           2  50623  Giglio v. United States
# 3           3  50632             Reed v. Reed
# 4           4  50643     Miller v. California
# 5           5  50644    Kleindienst v. Mandel
#
#                                       href   docket  term  \
# 1  https://api.oyez.org/cases/1971/70-5014  70-5014  1971
# 2    https://api.oyez.org/cases/1971/70-29    70-29  1971
# 3     https://api.oyez.org/cases/1971/70-4     70-4  1971
# 4    https://api.oyez.org/cases/1971/70-73    70-73  1971
# 5    https://api.oyez.org/cases/1971/71-16    71-16  1971
#
#                                          first_party  \
# 1                                Peter Stanley, Sr.
# 2                                       John Giglio
# 3                                         Sally Reed
# 4                                      Marvin Miller
# 5  Richard G. Kleindienst, Attorney General of th...
#
#                second_party  \
# 1                  Illinois
# 2             United States
# 3                Cecil Reed
# 4                California
# 5  Ernest E. Mandel, et al.
#
#                                                facts  facts_len  \
# 1  <p>Joan Stanley had three children with Peter ...        757
# 2  <p>John Giglio was convicted of passing forged...        495
# 3  <p>The Idaho Probate Code specified that "male...        378
# 4  <p>Miller, after conducting a mass mailing cam...        305
# 5  <p>Ernest E. Mandel was a Belgian professional...       2282
#
#    majority_vote  minority_vote first_party_winner     decision_type  \
# 1              5              2               True  majority opinion
# 2              7              0               True  majority opinion
# 3              7              0               True  majority opinion
# 4              5              4               True  majority opinion
# 5              6              3               True  majority opinion
#
#          disposition       issue_area
# 1  reversed/remanded     Civil Rights
# 2  reversed/remanded      Due Process
# 3  reversed/remanded     Civil Rights
# 4   vacated/remanded  First Amendment
# 5           reversed  First Amendment

# %% [markdown]
# ## Clean up the data
#
# drop unnecessary columns

# %%
df.drop(columns=['Unnamed: 0', 'href'])
# Out:
#          ID                                               name   docket  term  \
# 1     50613                                Stanley v. Illinois  70-5014  1971
# 2     50623                            Giglio v. United States    70-29  1971
# 3     50632                                       Reed v. Reed     70-4  1971
# 4     50643                               Miller v. California    70-73  1971
# 5     50644                              Kleindienst v. Mandel    71-16  1971
# ...     ...                                                ...      ...   ...
# 3297  63322  Yellen v. Confederated Tribes of the Chehalis ...   20-543  2020
# 3298  63324                  United States v. Palomar-Santiago   20-437  2020
# 3299  63323                             Terry v. United States  20-5904  2020
# 3300  63331                            United States v. Cooley  19-1414  2020
# 3302  63335                PennEast Pipeline Co. v. New Jersey  19-1039  2020
#
#                                             first_party  \
# 1                                   Peter Stanley, Sr.
# 2                                          John Giglio
# 3                                            Sally Reed
# 4                                         Marvin Miller
# 5     Richard G. Kleindienst, Attorney General of th...
# ...                                                 ...
# 3297         Janet L. Yellen, Secretary of the Treasury
# 3298                                      United States
# 3299                                    Tarahrick Terry
# 3300                                      United States
# 3302                          PennEast Pipeline Co. LLC
#
#                                            second_party  \
# 1                                              Illinois
# 2                                         United States
# 3                                            Cecil Reed
# 4                                            California
# 5                              Ernest E. Mandel, et al.
# ...                                                 ...
# 3297  Confederated Tribes of the Chehalis Reservatio...
# 3298                           Refugio Palomar-Santiago
# 3299                                      United States
# 3300                                Joshua James Cooley
# 3302                                 New Jersey, et al.
#
#                                                   facts  facts_len  \
# 1     <p>Joan Stanley had three children with Peter ...        757
# 2     <p>John Giglio was convicted of passing forged...        495
# 3     <p>The Idaho Probate Code specified that "male...        378
# 4     <p>Miller, after conducting a mass mailing cam...        305
# 5     <p>Ernest E. Mandel was a Belgian professional...       2282
# ...                                                 ...        ...
# 3297  <p>For over a century after the Alaska Purchas...       2340
# 3298  <p>Refugio Palomar-Santiago, a Mexican nationa...       2054
# 3299  <p>Tarahrick Terry pleaded guilty to one count...       1027
# 3300  <p>Joshua James Cooley was parked in his picku...       1309
# 3302  <p>The Natural Gas Act (NGA), 15 U.S.C. §§ 717...       1059
#
#       majority_vote  minority_vote first_party_winner     decision_type  \
# 1                 5              2               True  majority opinion
# 2                 7              0               True  majority opinion
# 3                 7              0               True  majority opinion
# 4                 5              4               True  majority opinion
# 5                 6              3               True  majority opinion
# ...             ...            ...                ...               ...
# 3297              6              3               True  majority opinion
# 3298              9              0               True  majority opinion
# 3299              9              0              False  majority opinion
# 3300              9              0               True  majority opinion
# 3302              5              4               True  majority opinion
#
#             disposition          issue_area
# 1     reversed/remanded        Civil Rights
# 2     reversed/remanded         Due Process
# 3     reversed/remanded        Civil Rights
# 4      vacated/remanded     First Amendment
# 5              reversed     First Amendment
# ...                 ...                 ...
# 3297  reversed/remanded        Civil Rights
# 3298  reversed/remanded  Criminal Procedure
# 3299           affirmed  Criminal Procedure
# 3300   vacated/remanded        Civil Rights
# 3302  reversed/remanded         Due Process
#
# [3098 rows x 14 columns]

# %%
print(df.first_party_winner.value_counts())
print(df.decision_type.value_counts())
# Out:
# True     2067
# False    1031
# Name: first_party_winner, dtype: int64
# majority opinion                     2723
# per curiam                            211
# plurality opinion                     145
# equally divided                        12
# dismissal - improvidently granted       3
# dismissal - other                       2
# dismissal - moot                        1
# opinion of the court                    1
# Name: decision_type, dtype: int64
